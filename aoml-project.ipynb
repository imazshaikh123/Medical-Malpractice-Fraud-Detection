# %% [markdown]
# # *AOML - Project*
# ## Medical Insurance Fraud Detection
# ### S040 - Imaz Shaikh
# ### S042 - Vikramaditya Singhai

# %%
# !pip install shutup
# Out:
# Collecting shutup
#   Downloading shutup-0.2.0-py3-none-any.whl.metadata (530 bytes)
# Downloading shutup-0.2.0-py3-none-any.whl (1.5 kB)
# Installing collected packages: shutup
# Successfully installed shutup-0.2.0

# %% [markdown]
# # *Imports*

# %%
import warnings
warnings.filterwarnings('ignore')
import shutup
shutup.please()
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor
import time
import optuna
from xgboost import  XGBRegressor, plot_importance
from catboost import  CatBoostRegressor
from lightgbm import  LGBMRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import  LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor 
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # *About The Data :*
# # The data set contains information about the last 79210 claim payments made.
#
# * #### Amount - Amount of the claim payment in dollars
# * #### Severity - The severity rating of damage to the patient, from 1 (emotional trauma) to 9 (death)
# * #### Age - Age of the claimant in years
# * #### Private Attorney - Whether the claimant was represented by a private attorney
# * #### Marital Status - Marital status of the claimant
# * #### Specialty - Specialty of the physician involved in the lawsuit
# * #### Insurance - Type of medical insurance carried by the patient
# * #### Gender - Patient Gender

# %%
df = pd.read_csv('/kaggle/input/medical-malpractice-insurance-dataset/medicalmalpractice.csv')

# %%
df
# Out:
#        Amount  Severity  Age  Private Attorney  Marital Status  \
# 0       57041         7   62                 1               2
# 1      324976         6   38                 1               2
# 2      135383         4   34                 1               2
# 3      829742         7   42                 1               1
# 4      197675         3   60                 0               2
# ...       ...       ...  ...               ...             ...
# 79205   25305         4   64                 1               2
# 79206   43098         3   87                 0               4
# 79207   35398         3   81                 0               4
# 79208  154228         9   19                 0               4
# 79209  168298         7    4                 1               1
#
#                 Specialty          Insurance  Gender
# 0         Family Practice            Private    Male
# 1                   OBGYN       No Insurance  Female
# 2              Cardiology            Unknown    Male
# 3              Pediatrics       No Insurance  Female
# 4                   OBGYN  Medicare/Medicaid  Female
# ...                   ...                ...     ...
# 79205     General Surgery            Unknown    Male
# 79206  Orthopedic Surgery            Unknown    Male
# 79207      Anesthesiology            Unknown    Male
# 79208         Dermatology            Unknown  Female
# 79209     Family Practice            Private  Female
#
# [79210 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79210 entries, 0 to 79209
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Amount            79210 non-null  int64
#  1   Severity          79210 non-null  int64
#  2   Age               79210 non-null  int64
#  3   Private Attorney  79210 non-null  int64
#  4   Marital Status    79210 non-null  int64
#  5   Specialty         79210 non-null  object
#  6   Insurance         79210 non-null  object
#  7   Gender            79210 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 4.8+ MB

# %%
df.describe()
# Out:
#               Amount      Severity           Age  Private Attorney  \
# count   79210.000000  79210.000000  79210.000000      79210.000000
# mean   157484.554816      4.799659     42.701868          0.660889
# std    193135.093293      2.083439     19.811063          0.473411
# min      1576.000000      1.000000      0.000000          0.000000
# 25%     43670.250000      3.000000     28.000000          0.000000
# 50%     98131.000000      4.000000     43.000000          1.000000
# 75%    154675.250000      7.000000     58.000000          1.000000
# max    926411.000000      9.000000     87.000000          1.000000
#
#        Marital Status
# count    79210.000000
# mean         1.889559
# std          1.002502
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000

# %%
new_column_names = {'Private Attorney': 'Private_Attorney', 'Marital Status': 'Marital_Status'}
df.rename(columns=new_column_names, inplace=True)
df
# Out:
#        Amount  Severity  Age  Private_Attorney  Marital_Status  \
# 0       57041         7   62                 1               2
# 1      324976         6   38                 1               2
# 2      135383         4   34                 1               2
# 3      829742         7   42                 1               1
# 4      197675         3   60                 0               2
# ...       ...       ...  ...               ...             ...
# 79205   25305         4   64                 1               2
# 79206   43098         3   87                 0               4
# 79207   35398         3   81                 0               4
# 79208  154228         9   19                 0               4
# 79209  168298         7    4                 1               1
#
#                 Specialty          Insurance  Gender
# 0         Family Practice            Private    Male
# 1                   OBGYN       No Insurance  Female
# 2              Cardiology            Unknown    Male
# 3              Pediatrics       No Insurance  Female
# 4                   OBGYN  Medicare/Medicaid  Female
# ...                   ...                ...     ...
# 79205     General Surgery            Unknown    Male
# 79206  Orthopedic Surgery            Unknown    Male
# 79207      Anesthesiology            Unknown    Male
# 79208         Dermatology            Unknown  Female
# 79209     Family Practice            Private  Female
#
# [79210 rows x 8 columns]

# %% [markdown]
# ## Conversion Of Num To String For OneHotEncoding

# %%
df['Private_Attorney'].replace(0, 'Not Private', inplace=True)
df['Private_Attorney'].replace(1, 'Private', inplace=True)

df['Marital_Status'].replace(0, 'Divorced', inplace=True)
df['Marital_Status'].replace(1, 'Single', inplace=True)
df['Marital_Status'].replace(2, 'Married', inplace=True)
df['Marital_Status'].replace(3, 'Widowed', inplace=True)
df['Marital_Status'].replace(4, 'Unknown', inplace=True)

# %% [markdown]
# # *EDA*

# %%
numeric_columns = ['Amount', 'Age']
for column in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=df, x=column, kde=True)
    plt.title(f'Histogram for {column}')
    plt.show()

# %% [markdown]
# * Histogram Of Amount Shows That The Majority of the values are Skewed To The Left. The amount greater than 154675.250000 are the outliers in our data. If we drop these values there would be reduction of 25% in our data.
# * Also as the 'Amount' is our target variable it cannot be standardized.
# * The Histogram Of Age Shows that the ages are ranging from New Borns to As High as 87 years Old. This is however normally distributed.

# %%
categorical_columns = ['Marital_Status', 'Insurance', 'Gender', 'Private_Attorney']
fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

for i, (column, ax) in enumerate(zip(categorical_columns, axes.flat)):
    category_counts = df[column].value_counts()
    ax.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=0)
    ax.set_title(f'Distribution of {column}')

plt.tight_layout()

plt.show()

# %% [markdown]
# Distribution of Marital_Status:
# * The majority (around 52%) are married.
# * Around 30% are single.
# * There are smaller percentages of divorced and unknown marital statuses (around 13% and 5%, respectively).
#
# Distribution of Insurance:
# * There seems to be a relatively even split between those with insurance (around 43%) and those without (around 57%).
#
# Distribution of Gender:
# * The data seems to be slightly skewed towards females (around 60%).
# * Males make up around 40%.
#
# Distribution of Private_Attorney:
# * There appears to be a larger proportion without a private attorney (around 66%).
# * Roughly one-third (around 34%) have a private attorney.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Severity', hue='Gender', palette='Set1')
plt.title('Severity by Gender')
plt.show()

# %% [markdown]
# This Shows that Females Have Reported A Fraud More Times In Most Of The Severity Levels As Compared To Males.

# %%
gender_amt = df.groupby('Gender').describe()['Amount']
gender_amt.transpose()
# Out:
# Gender         Female           Male
# count    47770.000000   31440.000000
# mean    150957.808290  167401.306775
# std     159467.182911  234897.588948
# min       1578.000000    1576.000000
# 25%      63112.500000   28414.250000
# 50%     111449.500000   66576.500000
# 75%     159819.500000  142946.250000
# max     851373.000000  926411.000000

# %% [markdown]
# There Is Very Minimal Difference In The Amount That is Payed By Both Males & Females And Majority Of The Payments Fall Under $160000

# %% [markdown]
# # *MODELLING*

# %%
categorical = ['Private_Attorney', 'Marital_Status', 'Specialty', 'Insurance', 'Gender']
df_final = pd.get_dummies(df, columns=categorical)
df_final
# Out:
#        Amount  Severity  Age  Private_Attorney_Not Private  \
# 0       57041         7   62                         False
# 1      324976         6   38                         False
# 2      135383         4   34                         False
# 3      829742         7   42                         False
# 4      197675         3   60                          True
# ...       ...       ...  ...                           ...
# 79205   25305         4   64                         False
# 79206   43098         3   87                          True
# 79207   35398         3   81                          True
# 79208  154228         9   19                          True
# 79209  168298         7    4                         False
#
#        Private_Attorney_Private  Marital_Status_Divorced  \
# 0                          True                    False
# 1                          True                    False
# 2                          True                    False
# 3                          True                    False
# 4                         False                    False
# ...                         ...                      ...
# 79205                      True                    False
# 79206                     False                    False
# 79207                     False                    False
# 79208                     False                    False
# 79209                      True                    False
#
#        Marital_Status_Married  Marital_Status_Single  Marital_Status_Unknown  \
# 0                        True                  False                   False
# 1                        True                  False                   False
# 2                        True                  False                   False
# 3                       False                   True                   False
# 4                        True                  False                   False
# ...                       ...                    ...                     ...
# 79205                    True                  False                   False
# 79206                   False                  False                    True
# 79207                   False                  False                    True
# 79208                   False                  False                    True
# 79209                   False                   True                   False
#
#        Marital_Status_Widowed  ...  Specialty_Resident  \
# 0                       False  ...               False
# 1                       False  ...               False
# 2                       False  ...               False
# 3                       False  ...               False
# 4                       False  ...               False
# ...                       ...  ...                 ...
# 79205                   False  ...               False
# 79206                   False  ...               False
# 79207                   False  ...               False
# 79208                   False  ...               False
# 79209                   False  ...               False
#
#        Specialty_Thoracic Surgery  Specialty_Urological Surgery  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# ...                           ...                           ...
# 79205                       False                         False
# 79206                       False                         False
# 79207                       False                         False
# 79208                       False                         False
# 79209                       False                         False
#
#        Insurance_Medicare/Medicaid  Insurance_No Insurance  Insurance_Private  \
# 0                            False                   False               True
# 1                            False                    True              False
# 2                            False                   False              False
# 3                            False                    True              False
# 4                             True                   False              False
# ...                            ...                     ...                ...
# 79205                        False                   False              False
# 79206                        False                   False              False
# 79207                        False                   False              False
# 79208                        False                   False              False
# 79209                        False                   False               True
#
#        Insurance_Unknown  Insurance_Workers Compensation  Gender_Female  \
# 0                  False                           False          False
# 1                  False                           False           True
# 2                   True                           False          False
# 3                  False                           False           True
# 4                  False                           False           True
# ...                  ...                             ...            ...
# 79205               True                           False          False
# 79206               True                           False          False
# 79207               True                           False          False
# 79208               True                           False           True
# 79209              False                           False           True
#
#        Gender_Male
# 0             True
# 1            False
# 2             True
# 3            False
# 4            False
# ...            ...
# 79205         True
# 79206         True
# 79207         True
# 79208        False
# 79209        False
#
# [79210 rows x 37 columns]

# %%
# To Test If Standardizing Yields Better Results

# %%
# categorical = ['Private_Attorney', 'Marital_Status', 'Specialty', 'Insurance', 'Gender']
# df_final = pd.get_dummies(df, columns=categorical, drop_first = True)
# df_final['Amount'] = StandardScaler().fit_transform(df[['Amount']])
# df_final

# %%
# To Remove The Outlier Values In Amount But Removes 25% Of The Data

# %%
# categorical = ['Private_Attorney', 'Marital_Status', 'Specialty', 'Insurance', 'Gender']
# df_final = pd.get_dummies(df, columns=categorical)
# df_final = df_final[df_final['Amount'] <= 154675.25]
# df_final

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df_final.corr(), cmap='jet', annot=True, annot_kws={"size": 5})
plt.show()

# %%
x = df_final.drop(["Amount"],axis=1)
y = df_final['Amount']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# # *Base Testing*

# %% [markdown]
# ## DECISION TREE BASE

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train,y_train)

dt_pred = dt_model.predict(x_test)
print('Root Mean Squared Error: ',mean_squared_error(y_test,dt_pred)**0.5)
print('R Square: ',r2_score(y_test,dt_pred))
# Out:
# Root Mean Squared Error:  139369.4841730343
# R Square:  0.4913004264081301

# %% [markdown]
# ## RANDOM FOREST BASE

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_train,y_train)

rf_pred = rf_model.predict(x_test)
print('Root Mean Squared Error: ',mean_squared_error(y_test,rf_pred)**0.5)
print('R Square: ',r2_score(y_test,rf_pred))
# Out:
# Root Mean Squared Error:  127395.28754313296
# R Square:  0.5749571498993806

# %% [markdown]
# ## GRADIENT BOOST BASE

# %%
gb_model = GradientBoostingRegressor(random_state=0)
gb_model.fit(x_train, y_train)
gb_pred = gb_model.predict(x_test)

print('Root Mean Squared Error: ', mean_squared_error(y_test, gb_pred)**0.5)
print('R Square: ', r2_score(y_test, gb_pred))
# Out:
# Root Mean Squared Error:  136690.51612972806
# R Square:  0.5106689717871641

# %% [markdown]
# ## LIGHTGBM BASE

# %%
lgbm_model = LGBMRegressor()
lgbm_model.fit(x_train,y_train)

lgbm_pred = lgbm_model.predict(x_test)
print('Root Mean Squared Error: ',mean_squared_error(y_test,lgbm_pred)**0.5)
print('R Square: ',r2_score(y_test,lgbm_pred))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008379 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 166
# [LightGBM] [Info] Number of data points in the train set: 63368, number of used features: 36
# [LightGBM] [Info] Start training from score 156908.754640
# Root Mean Squared Error:  116561.10761989614
# R Square:  0.6441775713644352

# %% [markdown]
# ## XGB MODEL BASE

# %%
xgb_model = XGBRegressor()
xgb_model.fit(x_train,y_train)

xgb_pred = xgb_model.predict(x_test)
print('Root Mean Squared Error: ',mean_squared_error(y_test,xgb_pred)**0.5)
print('R Square: ',r2_score(y_test,xgb_pred))
print("Mean Absolute Error: " + str(mean_absolute_error(xgb_pred, y_test)))
# Out:
# Root Mean Squared Error:  117345.93077461852
# R Square:  0.6393698301153754
# Mean Absolute Error: 73528.60413283059

# %% [markdown]
# ### We Will use XGB & LGBM for further testing as these are yielding the best results as of now on base models. The other models can be used and will be approached later as we may also try stacking. For now we try to get the best most score from these params with hyperparameter optimization

# %% [markdown]
# # *Hyperparameter Tuning With Modeling*

# %% [markdown]
# ## Cross Validation With XGB
# #### Basic Test As Base Model Was Not Giving Optimal Accuracy

# %%
# model = XGBRegressor()
# cv_scores = cross_val_score(model, x, y, cv=100, scoring='r2')

# print("Cross-Validation R-squared Scores:", cv_scores)

# mean_r2 = cv_scores.mean()
# print("Mean R-squared Score:", mean_r2)

# %% [markdown]
# ## XGB WITH RANDOMIZED SEARCH FOR PARAM RANGES

# %%
# param_grid = {
#     'n_estimators': range(100, 1000, 200), 
#     'learning_rate': [0.01, 0.05, 0.1],   
#     'max_depth': [3, 5, 8, 12],    
#     'min_child_weight': [1, 5, 10],
#     'gamma': [0, 0.5, 1],          
#     'reg_alpha': [0, 0.1, 1],       
#     'reg_lambda': [0, 0.1, 1],     
# }

# xgb_model = XGBRegressor(objective='reg:squarederror', verbosity=1) 

# rnd_search = RandomizedSearchCV(xgb_model, param_grid, n_iter=5, scoring='r2', cv=3, random_state=42, n_jobs=-1)

# rnd_search.fit(x_train, y_train)  

# print("Best parameters:", rnd_search.best_params_)
# best_model = rnd_search.best_estimator_

# best_model_pred = best_model.predict(x_test)
# print('Root Mean Squared Error (Best Model): ', mean_squared_error(y_test, best_model_pred)**0.5)
# print('R Square (Best Model): ', r2_score(y_test, best_model_pred))

# %% [markdown]
# ## XGB WITH OPTUNA
# #### Values Tuned With Results Taken From Randomized Search For XGB

# %%
# def objective(trial, x_train, y_train):
#     param_grid = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 150),
#         'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.07),
#         'num_leaves': trial.suggest_int('num_leaves', 80, 100),
#         'max_depth': trial.suggest_categorical('max_depth', [1, 5, 8]),
#         'lambda_l1': trial.suggest_float('lambda_l1', 0, 0.05),
#         'lambda_l2': trial.suggest_float('lambda_l2', 0, 0.2),
#     }

#     xgb_model = XGBRegressor(verbose=0, **param_grid)
#     xgb_model.fit(x_train, y_train)
#     preds = xgb_model.predict(x_test)

#     r2 = r2_score(y_test, preds)
#     return r2

# study = optuna.create_study(study_name='XGB OPTUNA', direction='maximize')
# study.optimize(lambda trial: objective(trial, x_train, y_train), n_trials=10)

# best_params = study.best_params
# best_model = XGBRegressor(verbose=0, **best_params)
# best_model.fit(x_train, y_train)

# best_model_pred = best_model.predict(x_test)
# print('Root Mean Squared Error (Best Model): ', np.sqrt(mean_squared_error(y_test, best_model_pred)))
# print('R Square (Best Model): ', r2_score(y_test, best_model_pred))

# %% [markdown]
# ## Cross Validation With LGBM
# #### Basic Test As Base Model Was Not Giving Optimal Accuracy

# %%
# model = LGBMRegressor(verbose=0)
# cv_scores = cross_val_score(model, x, y, cv=100, scoring='r2')

# print("Cross-Validation R-squared Scores:", cv_scores)

# mean_r2 = cv_scores.mean()
# print("Mean R-squared Score:", mean_r2)

# %% [markdown]
# ## LGBM WITH RANDOMIZED SEARCH FOR PARAM RANGES

# %%
# param_grid = {
#     'n_estimators': range(100, 1000, 200),
#     'learning_rate': [0.01, 0.05, 0.1],
#     'num_leaves': [31, 60, 90, 120],
#     'max_depth': [-1, 5, 8, 12],
#     'min_data_in_leaf': [20, 50, 100],
#     'lambda_l1': [0, 0.1, 1],
#     'lambda_l2': [0, 0.1, 1],
# }
# lgb_model = LGBMRegressor(verbose=0)

# rnd_search = RandomizedSearchCV(lgb_model, param_grid, n_iter=10, 
#                                 scoring='r2', cv=5, random_state=42, n_jobs=-1) 

# rnd_search.fit(x_train, y_train) 

# print("Best parameters:", rnd_search.best_params_)
# best_model = rnd_search.best_estimator_

# best_model_pred = best_model.predict(x_test)
# print('Root Mean Squared Error (Best Model): ', mean_squared_error(y_test, best_model_pred)**0.5)
# print('R Square (Best Model): ', r2_score(y_test, best_model_pred))

# %% [markdown]
# ## LGBM WITH GRID SEARCH FOR BASIC HYPERPARAM TUNING
# #### Values Tuned With Results From Randomized Search

# %%
# param_grid = {
#     'n_estimators': range(500, 1000, 100),
#     'learning_rate': [0.01, 0.05, 0.1],
#     'num_leaves': range(90, 180, 10),
#     'max_depth': [-1, 3, 5, 7, 9, 12, 15, 25],
#     'min_child_weight': [1, 3, 5, 7, 15, 25],
#     'reg_alpha': [0, 0.1],
#     'reg_lambda': [0, 0.1],
# }
# lgb_model = LGBMRegressor(verbose=1)

# grid_search = GridSearchCV(lgb_model, param_grid, scoring='r2', cv=5, n_jobs=-1)

# grid_search.fit(x_train, y_train)

# print("Best parameters:", grid_search.best_params_)
# best_model = grid_search.best_estimator_

# best_model_pred = best_model.predict(x_test)
# print('Root Mean Squared Error (Best Model): ', np.sqrt(mean_squared_error(y_test, best_model_pred)))
# print('R Square (Best Model): ', r2_score(y_test, best_model_pred))

# %% [markdown]
# ## LGBM WITH OPTUNA TUNING

# %%
# import optuna
# from lightgbm import LGBMRegressor
# from sklearn.metrics import mean_squared_error, r2_score

# def objective(trial, x_train, y_train):
#     param_grid = {
#         'num_leaves': trial.suggest_int('num_leaves', 40, 80),
#         'n_estimators': trial.suggest_int('n_estimators', 200, 400),
#         'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 30, 70),
#         'max_depth': trial.suggest_categorical('max_depth', [-1, 5, 8, 12]),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.2),
#         'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.5, 2.0),
#         'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.5, 2.0)
#     }

#     lgb_model = LGBMRegressor(verbose=0, **param_grid)
#     lgb_model.fit(x_train, y_train)
#     preds = lgb_model.predict(x_test)

#     r2 = r2_score(y_test, preds)
#     return r2

# study = optuna.create_study(study_name='LGBM OPTUNA', direction='maximize')
# study.optimize(lambda trial: objective(trial, x_train, y_train), n_trials=500)

# best_params = study.best_params
# best_model = LGBMRegressor(verbose=0, **best_params)
# best_model.fit(x_train, y_train)

# best_model_pred = best_model.predict(x_test)
# print('Root Mean Squared Error (Best Model): ', np.sqrt(mean_squared_error(y_test, best_model_pred)))
# print('R Square (Best Model): ', r2_score(y_test, best_model_pred))

# %% [markdown]
# # *Model Stacking*

# %% [markdown]
# ## MODEL STACKING : BASE LEARNER - XGB & LGBM, META LEARNER - LinearRegressor

# %%
# import optuna
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, r2_score
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# import numpy as np

# def xgb_objective(trial):
#     param_grid = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 150),
#         'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.07),
#         'num_leaves': trial.suggest_int('num_leaves', 80, 100),
#         'max_depth': trial.suggest_categorical('max_depth', [1, 5, 8]),
#         'lambda_l1': trial.suggest_float('lambda_l1', 0, 0.05),
#         'lambda_l2': trial.suggest_float('lambda_l2', 0, 0.2),
#     }
#     model = XGBRegressor(**param_grid)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     return r2_score(y_test, preds)

# with warnings.catch_warnings():
#     warnings.filterwarnings("ignore", message="No further splits with positive gain, best gain: -inf")

#     def lgbm_objective(trial):
#         param_grid = {
#             'num_leaves': trial.suggest_int('num_leaves', 80, 160),
#             'n_estimators': trial.suggest_int('n_estimators', 200, 400),
#             'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 60),
#             'max_depth': trial.suggest_categorical('max_depth', [-1, 5, 8, 12]),
#             'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.2),
#             'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.5, 2.0),
#             'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.5, 2.0)
#         }
#         model = LGBMRegressor(**param_grid)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         return r2_score(y_test, preds)

# xgb_study = optuna.create_study(study_name='XGB OPTUNA', direction='maximize')
# xgb_study.optimize(xgb_objective, n_trials=400)

# lgbm_study = optuna.create_study(study_name='LGBM OPTUNA', direction='maximize')
# lgbm_study.optimize(lgbm_objective, n_trials=400)

# best_xgb_params = xgb_study.best_params
# best_xgb_model = XGBRegressor(**best_xgb_params)
# best_xgb_model.fit(x_train, y_train)

# best_lgbm_params = lgbm_study.best_params
# best_lgbm_model = LGBMRegressor(**best_lgbm_params)
# best_lgbm_model.fit(x_train, y_train)

# xgb_preds = best_xgb_model.predict(x_test)
# lgbm_preds = best_lgbm_model.predict(x_test)

# stacked_features_train = np.column_stack((xgb_preds, lgbm_preds))

# meta_learner = LinearRegression()
# meta_learner.fit(stacked_features_train, y_test)

# stacked_features_test = np.column_stack((best_xgb_model.predict(x_test), best_lgbm_model.predict(x_test)))
# stacked_predictions = meta_learner.predict(stacked_features_test)

# print('Linear Regression As Meta Evaluation : ')
# print('Root Mean Squared Error (Stacked Model): ', np.sqrt(mean_squared_error(y_test, stacked_predictions)))
# print('R Square (Stacked Model): ', r2_score(y_test, stacked_predictions))

# %% [markdown]
# ## MODEL STACKING : BASE LEARNER - XGB & LGBM, META LEARNER - RandomForestRegressor

# %%
import optuna
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import numpy as np

def xgb_objective(trial):
    param_grid = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 150),
        'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.07),
        'num_leaves': trial.suggest_int('num_leaves', 80, 100),
        'max_depth': trial.suggest_categorical('max_depth', [1, 5, 8]),
        'lambda_l1': trial.suggest_float('lambda_l1', 0, 0.05),
        'lambda_l2': trial.suggest_float('lambda_l2', 0, 0.2),
    }
    model = XGBRegressor(**param_grid)
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    return r2_score(y_test, preds)

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="No further splits with positive gain, best gain: -inf")

    def lgbm_objective(trial):
        param_grid = {
            'num_leaves': trial.suggest_int('num_leaves', 80, 160),
            'n_estimators': trial.suggest_int('n_estimators', 200, 400),
            'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 60),
            'max_depth': trial.suggest_categorical('max_depth', [-1, 5, 8, 12]),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.2),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.5, 2.0),
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.5, 2.0)
        }
        model = LGBMRegressor(**param_grid)
        model.fit(x_train, y_train)
        preds = model.predict(x_test)
        return r2_score(y_test, preds)

xgb_study = optuna.create_study(study_name='XGB OPTUNA', direction='maximize')
xgb_study.optimize(xgb_objective, n_trials=400)

lgbm_study = optuna.create_study(study_name='LGBM OPTUNA', direction='maximize')
lgbm_study.optimize(lgbm_objective, n_trials=400)

best_xgb_params = xgb_study.best_params
best_xgb_model = XGBRegressor(**best_xgb_params)
best_xgb_model.fit(x_train, y_train)

best_lgbm_params = lgbm_study.best_params
best_lgbm_model = LGBMRegressor(**best_lgbm_params)
best_lgbm_model.fit(x_train, y_train)

xgb_preds = best_xgb_model.predict(x_test)
lgbm_preds = best_lgbm_model.predict(x_test)

stacked_features_train = np.column_stack((xgb_preds, lgbm_preds))

meta_learner = RandomForestRegressor()
meta_learner.fit(stacked_features_train, y_test)

stacked_features_test = np.column_stack((best_xgb_model.predict(x_test), best_lgbm_model.predict(x_test)))
stacked_predictions = meta_learner.predict(stacked_features_test)

print('Random Forest Regressor As Meta Evaluation : ')
print('Root Mean Squared Error (Stacked Model): ', np.sqrt(mean_squared_error(y_test, stacked_predictions)))
print('R Square (Stacked Model): ', r2_score(y_test, stacked_predictions))
# Out:
# [I 2024-04-06 11:16:37,882] A new study created in memory with name: XGB OPTUNA
# [I 2024-04-06 11:16:38,984] Trial 0 finished with value: 0.2187530053872293 and parameters: {'n_estimators': 64, 'learning_rate': 0.03442255775871442, 'num_leaves': 98, 'max_depth': 1, 'lambda_l1': 0.023347583973595293, 'lambda_l2': 0.13995174929575774}. Best is trial 0 with value: 0.2187530053872293.
# [I 2024-04-06 11:16:40,287] Trial 1 finished with value: 0.26568315885065674 and parameters: {'n_estimators': 83, 'learning_rate': 0.04906495308061584, 'num_leaves': 87, 'max_depth': 1, 'lambda_l1': 0.011968880030677326, 'lambda_l2': 0.08959689796230835}. Best is trial 1 with value: 0.26568315885065674.
# [I 2024-04-06 11:16:41,467] Trial 2 finished with value: 0.2702736116840665 and parameters: {'n_estimators': 71, 'learning_rate': 0.060949698253411524, 'num_leaves': 96, 'max_depth': 1, 'lambda_l1': 0.015057031697872238, 'lambda_l2': 0.07422353631142518}. Best is trial 2 with value: 0.2702736116840665.
# [I 2024-04-06 11:16:42,701] Trial 3 finished with value: 0.2757760988666518 and parameters: {'n_estimators': 76, 'learning_rate': 0.06224647861830671, 'num_leaves': 88, 'max_depth': 1, 'lambda_l1': 0.010433093184742904, 'lambda_l2': 0.13315560711500343}. Best is trial 3 with value: 0.2757760988666518.
# [I 2024-04-06 11:16:44,249] Trial 4 finished with value: 0.2614361133199209 and parameters: {'n_estimators': 108, 'learning_rate': 0.035622652327529966, 'num_leaves': 87, 'max_depth': 1, 'lambda_l1': 0.027369657952942196, 'lambda_l2': 0.04833351705077833}. Best is trial 3 with value: 0.2757760988666518.
# [I 2024-04-06 11:16:45,815] Trial 5 finished with value: 0.5560233903260259 and parameters: {'n_estimators': 56, 'learning_rate': 0.05568240783124487, 'num_leaves': 100, 'max_depth': 5, 'lambda_l1': 0.04442229068336782, 'lambda_l2': 0.039559591815727484}. Best is trial 5 with value: 0.5560233903260259.
# [I 2024-04-06 11:16:48,783] Trial 6 finished with value: 0.5872035124946409 and parameters: {'n_estimators': 144, 'learning_rate': 0.04718629296860975, 'num_leaves': 84, 'max_depth': 5, 'lambda_l1': 0.0008176801972803294, 'lambda_l2': 0.0721757263666261}. Best is trial 6 with value: 0.5872035124946409.
# [I 2024-04-06 11:16:50,119] Trial 7 finished with value: 0.2750133994100942 and parameters: {'n_estimators': 86, 'learning_rate': 0.054396306279508144, 'num_leaves': 91, 'max_depth': 1, 'lambda_l1': 0.012132708765906393, 'lambda_l2': 0.007376311441546247}. Best is trial 6 with value: 0.5872035124946409.
# [I 2024-04-06 11:16:52,064] Trial 8 finished with value: 0.5789835497353522 and parameters: {'n_estimators': 80, 'learning_rate': 0.06199315718208536, 'num_leaves': 85, 'max_depth': 5, 'lambda_l1': 0.034202218982608015, 'lambda_l2': 0.02723327324947782}. Best is trial 6 with value: 0.5872035124946409.
# [I 2024-04-06 11:16:54,759] Trial 9 finished with value: 0.5778829129300944 and parameters: {'n_estimators': 121, 'learning_rate': 0.04261111406884455, 'num_leaves': 99, 'max_depth': 5, 'lambda_l1': 0.041323317522103956, 'lambda_l2': 0.01867050662196983}. Best is trial 6 with value: 0.5872035124946409.
# [I 2024-04-06 11:16:59,051] Trial 10 finished with value: 0.6406532356839071 and parameters: {'n_estimators': 148, 'learning_rate': 0.04422944784223848, 'num_leaves': 80, 'max_depth': 8, 'lambda_l1': 0.0012154610036259708, 'lambda_l2': 0.19930509858156314}. Best is trial 10 with value: 0.6406532356839071.
# [I 2024-04-06 11:17:03,316] Trial 11 finished with value: 0.6419260331934804 and parameters: {'n_estimators': 148, 'learning_rate': 0.04453565895151696, 'num_leaves': 80, 'max_depth': 8, 'lambda_l1': 0.00034538468854680465, 'lambda_l2': 0.1904556703015038}. Best is trial 11 with value: 0.6419260331934804.
# [I 2024-04-06 11:17:07,595] Trial 12 finished with value: 0.6405218134076656 and parameters: {'n_estimators': 148, 'learning_rate': 0.04216108049587763, 'num_leaves': 80, 'max_depth': 8, 'lambda_l1': 8.486875709730633e-05, 'lambda_l2': 0.198690323835461}. Best is trial 11 with value: 0.6419260331934804.
# [I 2024-04-06 11:17:11,478] Trial 13 finished with value: 0.6381284455135205 and parameters: {'n_estimators': 129, 'learning_rate': 0.041608755271621556, 'num_leaves': 80, 'max_depth': 8, 'lambda_l1': 0.006168142792068398, 'lambda_l2': 0.18614940338032893}. Best is trial 11 with value: 0.6419260331934804.
# [I 2024-04-06 11:17:15,167] Trial 14 finished with value: 0.6418132156332458 and parameters: {'n_estimators': 132, 'learning_rate': 0.06966459491082877, 'num_leaves': 83, 'max_depth': 8, 'lambda_l1': 0.020444686341639928, 'lambda_l2': 0.1655738161274394}. Best is trial 11 with value: 0.6419260331934804.
# [I 2024-04-06 11:17:18,801] Trial 15 finished with value: 0.642700769773228 and parameters: {'n_estimators': 131, 'learning_rate': 0.06839427494137369, 'num_leaves': 83, 'max_depth': 8, 'lambda_l1': 0.020862122609188422, 'lambda_l2': 0.15528032996853616}. Best is trial 15 with value: 0.642700769773228.
# [I 2024-04-06 11:17:22,039] Trial 16 finished with value: 0.6394833323628055 and parameters: {'n_estimators': 107, 'learning_rate': 0.054041848017567014, 'num_leaves': 92, 'max_depth': 8, 'lambda_l1': 0.03091031947743918, 'lambda_l2': 0.1267053737937166}. Best is trial 15 with value: 0.642700769773228.
# [I 2024-04-06 11:17:26,283] Trial 17 finished with value: 0.6322925292452158 and parameters: {'n_estimators': 136, 'learning_rate': 0.03003168953269647, 'num_leaves': 82, 'max_depth': 8, 'lambda_l1': 0.037840278012065146, 'lambda_l2': 0.16629065037611865}. Best is trial 15 with value: 0.642700769773228.
# [I 2024-04-06 11:17:29,740] Trial 18 finished with value: 0.6423395696537293 and parameters: {'n_estimators': 119, 'learning_rate': 0.06903745393484684, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.018376360593613892, 'lambda_l2': 0.16524275058362714}. Best is trial 15 with value: 0.642700769773228.
# [I 2024-04-06 11:17:33,159] Trial 19 finished with value: 0.6440027763666478 and parameters: {'n_estimators': 118, 'learning_rate': 0.06988824100354127, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.018937284897750706, 'lambda_l2': 0.11024471144351247}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:36,179] Trial 20 finished with value: 0.6416015061601021 and parameters: {'n_estimators': 98, 'learning_rate': 0.06632694715803794, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.02663515706983839, 'lambda_l2': 0.10226150516631037}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:39,567] Trial 21 finished with value: 0.643384573907098 and parameters: {'n_estimators': 118, 'learning_rate': 0.06991894967848439, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.01971707367571059, 'lambda_l2': 0.15673730644579223}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:42,973] Trial 22 finished with value: 0.6411300667480531 and parameters: {'n_estimators': 118, 'learning_rate': 0.06544243310987638, 'num_leaves': 93, 'max_depth': 8, 'lambda_l1': 0.018852952838910135, 'lambda_l2': 0.11594146387920776}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:46,026] Trial 23 finished with value: 0.6421228025145416 and parameters: {'n_estimators': 100, 'learning_rate': 0.06531259168709143, 'num_leaves': 96, 'max_depth': 8, 'lambda_l1': 0.023647071824720093, 'lambda_l2': 0.15597884000855922}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:49,318] Trial 24 finished with value: 0.6408065136269157 and parameters: {'n_estimators': 111, 'learning_rate': 0.05847652958299502, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.03123578590533136, 'lambda_l2': 0.14708369940503524}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:52,946] Trial 25 finished with value: 0.6429039678968591 and parameters: {'n_estimators': 127, 'learning_rate': 0.06835158239619298, 'num_leaves': 96, 'max_depth': 8, 'lambda_l1': 0.017012857495013384, 'lambda_l2': 0.11972644369348384}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:55,769] Trial 26 finished with value: 0.6396280400771965 and parameters: {'n_estimators': 91, 'learning_rate': 0.06458259584207696, 'num_leaves': 96, 'max_depth': 8, 'lambda_l1': 0.006715676970746369, 'lambda_l2': 0.11360157707804995}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:17:59,317] Trial 27 finished with value: 0.6426842694509103 and parameters: {'n_estimators': 124, 'learning_rate': 0.058630816352348195, 'num_leaves': 97, 'max_depth': 8, 'lambda_l1': 0.014192437871085612, 'lambda_l2': 0.08691975191402625}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:03,245] Trial 28 finished with value: 0.6433927065771983 and parameters: {'n_estimators': 139, 'learning_rate': 0.06733026411998246, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.016606943637159595, 'lambda_l2': 0.114908262567435}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:06,153] Trial 29 finished with value: 0.5976119942996655 and parameters: {'n_estimators': 139, 'learning_rate': 0.06269033624871562, 'num_leaves': 90, 'max_depth': 5, 'lambda_l1': 0.023440166895185438, 'lambda_l2': 0.13634034873512052}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:09,489] Trial 30 finished with value: 0.6426901542904704 and parameters: {'n_estimators': 115, 'learning_rate': 0.06995194819929208, 'num_leaves': 94, 'max_depth': 8, 'lambda_l1': 0.007347672113821908, 'lambda_l2': 0.10478042146176265}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:13,035] Trial 31 finished with value: 0.6431946939151645 and parameters: {'n_estimators': 124, 'learning_rate': 0.0664752202423857, 'num_leaves': 98, 'max_depth': 8, 'lambda_l1': 0.01620417728028198, 'lambda_l2': 0.1227570731429305}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:16,183] Trial 32 finished with value: 0.6416714306690521 and parameters: {'n_estimators': 105, 'learning_rate': 0.067041854072058, 'num_leaves': 98, 'max_depth': 8, 'lambda_l1': 0.04951462143578669, 'lambda_l2': 0.09278216648150381}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:20,005] Trial 33 finished with value: 0.6421164680970175 and parameters: {'n_estimators': 137, 'learning_rate': 0.058941280707570244, 'num_leaves': 92, 'max_depth': 8, 'lambda_l1': 0.02136126921557401, 'lambda_l2': 0.075226786485372}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:21,636] Trial 34 finished with value: 0.3018988378194818 and parameters: {'n_estimators': 113, 'learning_rate': 0.06381192576155956, 'num_leaves': 95, 'max_depth': 1, 'lambda_l1': 0.015621348190972812, 'lambda_l2': 0.14106376542032514}. Best is trial 19 with value: 0.6440027763666478.
# [I 2024-04-06 11:18:25,190] Trial 35 finished with value: 0.6440046893234237 and parameters: {'n_estimators': 124, 'learning_rate': 0.0674922627195761, 'num_leaves': 98, 'max_depth': 8, 'lambda_l1': 0.01182714252480998, 'lambda_l2': 0.10979429490890054}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:27,119] Trial 36 finished with value: 0.31088513042297705 and parameters: {'n_estimators': 141, 'learning_rate': 0.06005594398968228, 'num_leaves': 100, 'max_depth': 1, 'lambda_l1': 0.009504646525913173, 'lambda_l2': 0.07611656898637732}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:30,120] Trial 37 finished with value: 0.6366434731063235 and parameters: {'n_estimators': 94, 'learning_rate': 0.05002605638339061, 'num_leaves': 92, 'max_depth': 8, 'lambda_l1': 0.01231036459055111, 'lambda_l2': 0.059955423710577486}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:31,967] Trial 38 finished with value: 0.30406961489114626 and parameters: {'n_estimators': 134, 'learning_rate': 0.05634215202516223, 'num_leaves': 97, 'max_depth': 1, 'lambda_l1': 0.02643651259443881, 'lambda_l2': 0.09126467897209836}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:33,735] Trial 39 finished with value: 0.5708837175157764 and parameters: {'n_estimators': 63, 'learning_rate': 0.06328607667002457, 'num_leaves': 95, 'max_depth': 5, 'lambda_l1': 0.004352849606777023, 'lambda_l2': 0.1103821068214776}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:37,324] Trial 40 finished with value: 0.6430962408602483 and parameters: {'n_estimators': 125, 'learning_rate': 0.06752799192540548, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.013047973439252968, 'lambda_l2': 0.12777110201687855}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:40,905] Trial 41 finished with value: 0.6433505460931249 and parameters: {'n_estimators': 122, 'learning_rate': 0.06653627735437444, 'num_leaves': 98, 'max_depth': 8, 'lambda_l1': 0.009869443285060293, 'lambda_l2': 0.12544423008161476}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:44,317] Trial 42 finished with value: 0.64214553276121 and parameters: {'n_estimators': 116, 'learning_rate': 0.06154882074347854, 'num_leaves': 100, 'max_depth': 8, 'lambda_l1': 0.010643800063555685, 'lambda_l2': 0.14346997690298585}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:48,214] Trial 43 finished with value: 0.6426649457047025 and parameters: {'n_estimators': 142, 'learning_rate': 0.06994678376707945, 'num_leaves': 99, 'max_depth': 8, 'lambda_l1': 0.010201071730029206, 'lambda_l2': 0.09884194427069098}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:51,716] Trial 44 finished with value: 0.6422405699923199 and parameters: {'n_estimators': 121, 'learning_rate': 0.06482915549388406, 'num_leaves': 97, 'max_depth': 8, 'lambda_l1': 0.014422541659649912, 'lambda_l2': 0.13318699988363325}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:54,132] Trial 45 finished with value: 0.5933503487000569 and parameters: {'n_estimators': 110, 'learning_rate': 0.06706098025076766, 'num_leaves': 95, 'max_depth': 5, 'lambda_l1': 0.0040639062346609685, 'lambda_l2': 0.0848323592641021}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:58,041] Trial 46 finished with value: 0.6368617304024756 and parameters: {'n_estimators': 129, 'learning_rate': 0.03781551050210669, 'num_leaves': 99, 'max_depth': 8, 'lambda_l1': 0.017687731087758368, 'lambda_l2': 0.1755567917117387}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:18:59,601] Trial 47 finished with value: 0.2828224873649625 and parameters: {'n_estimators': 104, 'learning_rate': 0.05102103476951632, 'num_leaves': 87, 'max_depth': 1, 'lambda_l1': 0.00839584828205456, 'lambda_l2': 0.10156130945070581}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:19:03,119] Trial 48 finished with value: 0.642210001015855 and parameters: {'n_estimators': 121, 'learning_rate': 0.061024702258808176, 'num_leaves': 93, 'max_depth': 8, 'lambda_l1': 0.019848320096421623, 'lambda_l2': 0.1516629344085411}. Best is trial 35 with value: 0.6440046893234237.
# [I 2024-04-06 11:19:06,946] Trial 49 finished with value: 0.6447892451402093 and parameters: {'n_estimators': 132, 'learning_rate': 0.06797657755815133, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.02159900867200487, 'lambda_l2': 0.10913364921653772}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:10,948] Trial 50 finished with value: 0.6428976497518375 and parameters: {'n_estimators': 146, 'learning_rate': 0.06826127516586009, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.02843871144994048, 'lambda_l2': 0.044399324479353075}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:14,700] Trial 51 finished with value: 0.6428107687529747 and parameters: {'n_estimators': 132, 'learning_rate': 0.06573387035198887, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.022141357816893293, 'lambda_l2': 0.1257530167888852}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:16,642] Trial 52 finished with value: 0.6226004064132001 and parameters: {'n_estimators': 51, 'learning_rate': 0.06335309048061628, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.024623674616886883, 'lambda_l2': 0.11050357681926845}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:20,449] Trial 53 finished with value: 0.6438282415559566 and parameters: {'n_estimators': 136, 'learning_rate': 0.06798344845239113, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.014423677184695298, 'lambda_l2': 0.06488225807040117}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:24,233] Trial 54 finished with value: 0.6423468229798851 and parameters: {'n_estimators': 136, 'learning_rate': 0.06849191976802088, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.019100219461347167, 'lambda_l2': 0.05502574697817754}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:28,211] Trial 55 finished with value: 0.6431541446271798 and parameters: {'n_estimators': 144, 'learning_rate': 0.0698145923465114, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.014002009637144429, 'lambda_l2': 0.023708277173519268}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:30,891] Trial 56 finished with value: 0.5991357673614897 and parameters: {'n_estimators': 128, 'learning_rate': 0.06802975719221042, 'num_leaves': 93, 'max_depth': 5, 'lambda_l1': 0.016458565766501166, 'lambda_l2': 0.06466738640827298}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:34,641] Trial 57 finished with value: 0.6426054727643048 and parameters: {'n_estimators': 134, 'learning_rate': 0.06436761157396041, 'num_leaves': 93, 'max_depth': 8, 'lambda_l1': 0.022572578485437218, 'lambda_l2': 0.03523517320322232}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:38,701] Trial 58 finished with value: 0.644255397929261 and parameters: {'n_estimators': 141, 'learning_rate': 0.06746837877123137, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.012005880903505326, 'lambda_l2': 0.08081759663781843}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:42,885] Trial 59 finished with value: 0.6433054498212685 and parameters: {'n_estimators': 150, 'learning_rate': 0.062410301147236766, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.0113340204746973, 'lambda_l2': 0.08317399297357689}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:46,863] Trial 60 finished with value: 0.6431978034768961 and parameters: {'n_estimators': 140, 'learning_rate': 0.06007120019413601, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.012684696050936589, 'lambda_l2': 0.09638616714853776}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:50,558] Trial 61 finished with value: 0.6431427142950826 and parameters: {'n_estimators': 130, 'learning_rate': 0.0656909015061141, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.018508551582483376, 'lambda_l2': 0.06510250429963942}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:54,619] Trial 62 finished with value: 0.6444873243536576 and parameters: {'n_estimators': 145, 'learning_rate': 0.06759031790022768, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.014808988321964787, 'lambda_l2': 0.07827376227319202}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:19:58,655] Trial 63 finished with value: 0.6444214524307514 and parameters: {'n_estimators': 144, 'learning_rate': 0.06735741623801571, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.016453631759628547, 'lambda_l2': 0.10695714809409063}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:02,445] Trial 64 finished with value: 0.6421919269022285 and parameters: {'n_estimators': 134, 'learning_rate': 0.0684907690390203, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.014083338174354297, 'lambda_l2': 0.07960270360488929}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:06,660] Trial 65 finished with value: 0.6422565461435582 and parameters: {'n_estimators': 145, 'learning_rate': 0.046827061010973794, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.020672459758151355, 'lambda_l2': 0.07155951853555605}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:10,856] Trial 66 finished with value: 0.6435154087200161 and parameters: {'n_estimators': 148, 'learning_rate': 0.06458613857373278, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.008097755983235318, 'lambda_l2': 0.10397528769631814}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:14,745] Trial 67 finished with value: 0.6428090042238161 and parameters: {'n_estimators': 138, 'learning_rate': 0.06626174180742045, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.01562297291010063, 'lambda_l2': 0.09257524161820871}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:16,744] Trial 68 finished with value: 0.31951027789941233 and parameters: {'n_estimators': 142, 'learning_rate': 0.06902643456161892, 'num_leaves': 89, 'max_depth': 1, 'lambda_l1': 0.01764462581518982, 'lambda_l2': 0.05116254017314127}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:20,897] Trial 69 finished with value: 0.6447006109614376 and parameters: {'n_estimators': 150, 'learning_rate': 0.06755235728176223, 'num_leaves': 85, 'max_depth': 8, 'lambda_l1': 0.00512181016521942, 'lambda_l2': 0.068088474261376}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:24,212] Trial 70 finished with value: 0.5749420051452465 and parameters: {'n_estimators': 150, 'learning_rate': 0.031068539445166795, 'num_leaves': 84, 'max_depth': 5, 'lambda_l1': 0.0016426759013301422, 'lambda_l2': 0.10777464169914014}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:28,233] Trial 71 finished with value: 0.6438265843558206 and parameters: {'n_estimators': 144, 'learning_rate': 0.06740904493487007, 'num_leaves': 85, 'max_depth': 8, 'lambda_l1': 0.005113337075613733, 'lambda_l2': 0.06994947449620409}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:32,269] Trial 72 finished with value: 0.6429615456510982 and parameters: {'n_estimators': 146, 'learning_rate': 0.06559140529555457, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.002396342039947985, 'lambda_l2': 0.057702142931609406}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:36,070] Trial 73 finished with value: 0.6436520909337342 and parameters: {'n_estimators': 136, 'learning_rate': 0.06898354158046538, 'num_leaves': 81, 'max_depth': 8, 'lambda_l1': 0.012046649259474868, 'lambda_l2': 0.08215693450627753}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:39,749] Trial 74 finished with value: 0.6427554622806577 and parameters: {'n_estimators': 126, 'learning_rate': 0.06397706568196124, 'num_leaves': 85, 'max_depth': 8, 'lambda_l1': 0.006455445896413913, 'lambda_l2': 0.11929202916176873}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:43,685] Trial 75 finished with value: 0.6435918235323623 and parameters: {'n_estimators': 141, 'learning_rate': 0.06744589646651131, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.008994514033974109, 'lambda_l2': 0.06762612479457833}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:47,435] Trial 76 finished with value: 0.643133373545451 and parameters: {'n_estimators': 132, 'learning_rate': 0.06628283189107557, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.025199238237320228, 'lambda_l2': 0.08866606328831628}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:49,977] Trial 77 finished with value: 0.6350541432080977 and parameters: {'n_estimators': 78, 'learning_rate': 0.0626655197316905, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.013299065153732087, 'lambda_l2': 0.07659591107085291}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:54,028] Trial 78 finished with value: 0.6424856369897542 and parameters: {'n_estimators': 147, 'learning_rate': 0.0688672015437765, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.015337095528615141, 'lambda_l2': 0.09739335171439019}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:57,904] Trial 79 finished with value: 0.643940152668548 and parameters: {'n_estimators': 138, 'learning_rate': 0.06500307463108648, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.020994201499285714, 'lambda_l2': 0.0375545270842887}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:20:59,864] Trial 80 finished with value: 0.31650306277337004 and parameters: {'n_estimators': 143, 'learning_rate': 0.06497140676684232, 'num_leaves': 84, 'max_depth': 1, 'lambda_l1': 0.021828508355805992, 'lambda_l2': 0.013940293453966718}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:03,695] Trial 81 finished with value: 0.6428694653381897 and parameters: {'n_estimators': 139, 'learning_rate': 0.0670955047533496, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.017570361328294773, 'lambda_l2': 0.04057536575010978}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:07,429] Trial 82 finished with value: 0.642285551105777 and parameters: {'n_estimators': 134, 'learning_rate': 0.06936187389382742, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.01131580511895679, 'lambda_l2': 0.0317185859714159}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:11,337] Trial 83 finished with value: 0.6435603440296862 and parameters: {'n_estimators': 137, 'learning_rate': 0.0678375243156105, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.019646381638921212, 'lambda_l2': 0.11760635013770683}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:15,387] Trial 84 finished with value: 0.6428713227892453 and parameters: {'n_estimators': 143, 'learning_rate': 0.06626292689866466, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.029268042473897523, 'lambda_l2': 0.04717005056720497}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:19,546] Trial 85 finished with value: 0.6435025757205459 and parameters: {'n_estimators': 150, 'learning_rate': 0.06388295142298532, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.015031990160850323, 'lambda_l2': 0.0623337400993321}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:23,268] Trial 86 finished with value: 0.6432275140766144 and parameters: {'n_estimators': 132, 'learning_rate': 0.06775262335709634, 'num_leaves': 92, 'max_depth': 8, 'lambda_l1': 0.023847743421119956, 'lambda_l2': 0.10899150003443807}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:27,126] Trial 87 finished with value: 0.6384977058948067 and parameters: {'n_estimators': 127, 'learning_rate': 0.040282522307621985, 'num_leaves': 83, 'max_depth': 8, 'lambda_l1': 0.020900380984681957, 'lambda_l2': 0.005414708533960602}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:29,170] Trial 88 finished with value: 0.5861713240571653 and parameters: {'n_estimators': 86, 'learning_rate': 0.0698833453058506, 'num_leaves': 87, 'max_depth': 5, 'lambda_l1': 0.018108749965995326, 'lambda_l2': 0.0941215771674416}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:33,041] Trial 89 finished with value: 0.6440240264640793 and parameters: {'n_estimators': 140, 'learning_rate': 0.06531941370253924, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.016684492446897112, 'lambda_l2': 0.08745778677047383}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:37,177] Trial 90 finished with value: 0.6420873580944317 and parameters: {'n_estimators': 148, 'learning_rate': 0.057431438290849936, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.025766081578856632, 'lambda_l2': 0.08820762368563237}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:41,054] Trial 91 finished with value: 0.6437211070410016 and parameters: {'n_estimators': 141, 'learning_rate': 0.06674022409421625, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.016316882607626364, 'lambda_l2': 0.10122275161796418}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:45,018] Trial 92 finished with value: 0.643645680590085 and parameters: {'n_estimators': 139, 'learning_rate': 0.06558925272495306, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.019083419177404897, 'lambda_l2': 0.07807616116100724}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:48,817] Trial 93 finished with value: 0.6426151270013547 and parameters: {'n_estimators': 136, 'learning_rate': 0.06858347396845109, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.022608505426055414, 'lambda_l2': 0.11485263413473772}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:52,383] Trial 94 finished with value: 0.6413618900222744 and parameters: {'n_estimators': 124, 'learning_rate': 0.06147860909379795, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.013401523106067582, 'lambda_l2': 0.1064626851049981}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:56,442] Trial 95 finished with value: 0.6426044619562858 and parameters: {'n_estimators': 145, 'learning_rate': 0.05379064716634678, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.016865301657058726, 'lambda_l2': 0.1309521349794946}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:21:58,831] Trial 96 finished with value: 0.6360258973380246 and parameters: {'n_estimators': 71, 'learning_rate': 0.0649100652330835, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.011420575416996809, 'lambda_l2': 9.429158878740407e-05}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:02,480] Trial 97 finished with value: 0.6413028188231691 and parameters: {'n_estimators': 130, 'learning_rate': 0.06336649718860118, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.014626931670918409, 'lambda_l2': 0.07391547306320366}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:05,859] Trial 98 finished with value: 0.6423287184097403 and parameters: {'n_estimators': 117, 'learning_rate': 0.06786711539002299, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.037614526763210254, 'lambda_l2': 0.0809612588424081}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:07,777] Trial 99 finished with value: 0.3159003849302625 and parameters: {'n_estimators': 138, 'learning_rate': 0.06663612430490742, 'num_leaves': 88, 'max_depth': 1, 'lambda_l1': 0.019637541738235842, 'lambda_l2': 0.0552955047077838}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:11,885] Trial 100 finished with value: 0.6419512246544152 and parameters: {'n_estimators': 148, 'learning_rate': 0.060107918638528934, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.010496099958903658, 'lambda_l2': 0.12118087490396157}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:15,994] Trial 101 finished with value: 0.6421333073972257 and parameters: {'n_estimators': 142, 'learning_rate': 0.06709109826209433, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.003917085194424295, 'lambda_l2': 0.07071284321542602}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:20,015] Trial 102 finished with value: 0.6439486637080496 and parameters: {'n_estimators': 145, 'learning_rate': 0.06913705165936224, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.006285254368351603, 'lambda_l2': 0.08496293840206638}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:24,065] Trial 103 finished with value: 0.6437336974169499 and parameters: {'n_estimators': 146, 'learning_rate': 0.06923843243845243, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.005270870695720641, 'lambda_l2': 0.08582991269357026}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:27,837] Trial 104 finished with value: 0.6424417392469046 and parameters: {'n_estimators': 134, 'learning_rate': 0.06826064040661106, 'num_leaves': 84, 'max_depth': 8, 'lambda_l1': 0.008390776791694915, 'lambda_l2': 0.11285382767812384}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:31,848] Trial 105 finished with value: 0.6435617890509401 and parameters: {'n_estimators': 144, 'learning_rate': 0.06594780430030758, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.0074120447119136856, 'lambda_l2': 0.09721629821846337}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:35,834] Trial 106 finished with value: 0.643946900896915 and parameters: {'n_estimators': 141, 'learning_rate': 0.06922954007145586, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.015946595177461723, 'lambda_l2': 0.10205503174970794}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:39,755] Trial 107 finished with value: 0.6430239704024042 and parameters: {'n_estimators': 140, 'learning_rate': 0.06957122940749409, 'num_leaves': 85, 'max_depth': 8, 'lambda_l1': 0.0022675987330794457, 'lambda_l2': 0.09099864155682989}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:43,852] Trial 108 finished with value: 0.6437588997775902 and parameters: {'n_estimators': 149, 'learning_rate': 0.06519871052965438, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.015950459962669798, 'lambda_l2': 0.10371468954034793}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:46,842] Trial 109 finished with value: 0.6016587330590298 and parameters: {'n_estimators': 146, 'learning_rate': 0.06999231371528175, 'num_leaves': 97, 'max_depth': 5, 'lambda_l1': 0.003314226190075496, 'lambda_l2': 0.0950384975448692}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:50,829] Trial 110 finished with value: 0.6441354111850248 and parameters: {'n_estimators': 143, 'learning_rate': 0.0687612887251634, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.017385849315682815, 'lambda_l2': 0.1003769622752314}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:54,778] Trial 111 finished with value: 0.6431994755451442 and parameters: {'n_estimators': 143, 'learning_rate': 0.0688929748763128, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.01851205449567899, 'lambda_l2': 0.09980673684490957}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:22:58,072] Trial 112 finished with value: 0.6430678821808601 and parameters: {'n_estimators': 114, 'learning_rate': 0.06750188003198389, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.01716446131814898, 'lambda_l2': 0.1103602133627784}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:01,916] Trial 113 finished with value: 0.6425399375668652 and parameters: {'n_estimators': 140, 'learning_rate': 0.06858847660722606, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.02109874552634662, 'lambda_l2': 0.08506812027374633}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:05,939] Trial 114 finished with value: 0.6427564976780256 and parameters: {'n_estimators': 147, 'learning_rate': 0.06677786891185705, 'num_leaves': 85, 'max_depth': 8, 'lambda_l1': 0.012928233874612614, 'lambda_l2': 0.10491846566679167}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:09,812] Trial 115 finished with value: 0.6430426847817923 and parameters: {'n_estimators': 137, 'learning_rate': 0.06453511727640952, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.020316973106934838, 'lambda_l2': 0.08815594939626246}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:13,753] Trial 116 finished with value: 0.6419702575960539 and parameters: {'n_estimators': 142, 'learning_rate': 0.06591930450877359, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.015377072200657546, 'lambda_l2': 0.12299838880598352}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:17,215] Trial 117 finished with value: 0.6425408310621296 and parameters: {'n_estimators': 120, 'learning_rate': 0.06914593680832698, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.00012323696539895661, 'lambda_l2': 0.10013041154170713}. Best is trial 49 with value: 0.6447892451402093.
# [I 2024-04-06 11:23:21,249] Trial 118 finished with value: 0.6455308163692401 and parameters: {'n_estimators': 144, 'learning_rate': 0.06796962071354848, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.024204064206165776, 'lambda_l2': 0.11419829147335978}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:25,219] Trial 119 finished with value: 0.6442086901504411 and parameters: {'n_estimators': 144, 'learning_rate': 0.06817713001441994, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.026902927129737093, 'lambda_l2': 0.11481031820233067}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:29,220] Trial 120 finished with value: 0.6429792076470887 and parameters: {'n_estimators': 145, 'learning_rate': 0.0680806899727281, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.03202906604358984, 'lambda_l2': 0.11321352953787892}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:33,275] Trial 121 finished with value: 0.6435475012792785 and parameters: {'n_estimators': 150, 'learning_rate': 0.06722029268546566, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.027093885569366555, 'lambda_l2': 0.1149737692032341}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:37,241] Trial 122 finished with value: 0.6436203025451772 and parameters: {'n_estimators': 144, 'learning_rate': 0.06917327683993675, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.027920428192135128, 'lambda_l2': 0.10647788734018462}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:41,304] Trial 123 finished with value: 0.643867118298423 and parameters: {'n_estimators': 147, 'learning_rate': 0.06800465725922666, 'num_leaves': 86, 'max_depth': 8, 'lambda_l1': 0.02464472211475781, 'lambda_l2': 0.12928590737057774}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:45,192] Trial 124 finished with value: 0.6436534771266542 and parameters: {'n_estimators': 140, 'learning_rate': 0.06650090070993443, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.02278299114245825, 'lambda_l2': 0.10892383093525107}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:47,148] Trial 125 finished with value: 0.31821301544052394 and parameters: {'n_estimators': 142, 'learning_rate': 0.067427106149779, 'num_leaves': 89, 'max_depth': 1, 'lambda_l1': 0.029795391581198177, 'lambda_l2': 0.09285949016663576}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:51,145] Trial 126 finished with value: 0.6432959443933146 and parameters: {'n_estimators': 133, 'learning_rate': 0.06863684729346271, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.023569637493899287, 'lambda_l2': 0.08026368416966348}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:55,013] Trial 127 finished with value: 0.6441724754035336 and parameters: {'n_estimators': 135, 'learning_rate': 0.0699734742499927, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.026292482231456287, 'lambda_l2': 0.13661275282081814}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:23:58,798] Trial 128 finished with value: 0.6431018039961802 and parameters: {'n_estimators': 135, 'learning_rate': 0.0698584860978389, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.026005486746389268, 'lambda_l2': 0.14702619654874935}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:01,428] Trial 129 finished with value: 0.5971509931119692 and parameters: {'n_estimators': 123, 'learning_rate': 0.0659951499473246, 'num_leaves': 95, 'max_depth': 5, 'lambda_l1': 0.024484491707638764, 'lambda_l2': 0.13434126142707906}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:05,135] Trial 130 finished with value: 0.6429315867327756 and parameters: {'n_estimators': 131, 'learning_rate': 0.06821334735522462, 'num_leaves': 83, 'max_depth': 8, 'lambda_l1': 0.005825184062008857, 'lambda_l2': 0.12049428523707477}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:09,110] Trial 131 finished with value: 0.643889555447593 and parameters: {'n_estimators': 145, 'learning_rate': 0.06899063392077773, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.017148531180139894, 'lambda_l2': 0.13941277971656338}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:12,953] Trial 132 finished with value: 0.6440016809444906 and parameters: {'n_estimators': 138, 'learning_rate': 0.06713266832700565, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.00933167720593549, 'lambda_l2': 0.10174783560049343}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:16,634] Trial 133 finished with value: 0.6444730296710295 and parameters: {'n_estimators': 128, 'learning_rate': 0.06710161069901859, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.0075369968623077, 'lambda_l2': 0.11831171885351274}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:20,250] Trial 134 finished with value: 0.6433928244856422 and parameters: {'n_estimators': 125, 'learning_rate': 0.06705519185698794, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.009580309195788802, 'lambda_l2': 0.11866525831473868}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:23,986] Trial 135 finished with value: 0.6431608661735522 and parameters: {'n_estimators': 128, 'learning_rate': 0.06558975323039531, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.01164321662232871, 'lambda_l2': 0.11024339005300163}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:27,893] Trial 136 finished with value: 0.6434402561778706 and parameters: {'n_estimators': 138, 'learning_rate': 0.06658731300694835, 'num_leaves': 90, 'max_depth': 8, 'lambda_l1': 0.007717836750393769, 'lambda_l2': 0.12258984120042452}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:31,507] Trial 137 finished with value: 0.6425833170343299 and parameters: {'n_estimators': 129, 'learning_rate': 0.06790618414762609, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.04626404287243417, 'lambda_l2': 0.11650013296487831}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:35,228] Trial 138 finished with value: 0.6433530937136239 and parameters: {'n_estimators': 132, 'learning_rate': 0.06998765178628245, 'num_leaves': 91, 'max_depth': 8, 'lambda_l1': 0.00913345736034845, 'lambda_l2': 0.12758442647240684}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:39,144] Trial 139 finished with value: 0.6411399895344447 and parameters: {'n_estimators': 136, 'learning_rate': 0.05309648849417317, 'num_leaves': 92, 'max_depth': 8, 'lambda_l1': 0.010862381996540289, 'lambda_l2': 0.0983355754897649}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:42,753] Trial 140 finished with value: 0.6427002579367305 and parameters: {'n_estimators': 127, 'learning_rate': 0.0674557884315828, 'num_leaves': 99, 'max_depth': 8, 'lambda_l1': 0.012373584307024371, 'lambda_l2': 0.11226492988614545}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:46,817] Trial 141 finished with value: 0.6429134328274057 and parameters: {'n_estimators': 148, 'learning_rate': 0.06851585277748687, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.006245624554778132, 'lambda_l2': 0.07473335771837442}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:49,734] Trial 142 finished with value: 0.640933515990364 and parameters: {'n_estimators': 94, 'learning_rate': 0.0668075575345324, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.013649461445084315, 'lambda_l2': 0.10338340101501495}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:53,779] Trial 143 finished with value: 0.6428543967759341 and parameters: {'n_estimators': 143, 'learning_rate': 0.0680821191217519, 'num_leaves': 89, 'max_depth': 8, 'lambda_l1': 0.026396276452605515, 'lambda_l2': 0.0902211494945303}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:24:57,722] Trial 144 finished with value: 0.6446468822535262 and parameters: {'n_estimators': 139, 'learning_rate': 0.0693292692679921, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.0065536203156972795, 'lambda_l2': 0.08347003873796392}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:01,641] Trial 145 finished with value: 0.6433477508317567 and parameters: {'n_estimators': 139, 'learning_rate': 0.06396936185913613, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.0072370771482064365, 'lambda_l2': 0.09373469101477443}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:05,475] Trial 146 finished with value: 0.6435955167088125 and parameters: {'n_estimators': 135, 'learning_rate': 0.0653102366901206, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.027728404358031967, 'lambda_l2': 0.10697303995164319}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:07,448] Trial 147 finished with value: 0.29356586965543674 and parameters: {'n_estimators': 141, 'learning_rate': 0.044966597780856654, 'num_leaves': 89, 'max_depth': 1, 'lambda_l1': 0.005032830708836307, 'lambda_l2': 0.1248269591313757}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:11,340] Trial 148 finished with value: 0.6441943415510565 and parameters: {'n_estimators': 139, 'learning_rate': 0.0674922793270484, 'num_leaves': 82, 'max_depth': 8, 'lambda_l1': 0.009813723707559, 'lambda_l2': 0.06901587421558115}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:15,001] Trial 149 finished with value: 0.6427454017852887 and parameters: {'n_estimators': 131, 'learning_rate': 0.06883378532367843, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.028717719746854265, 'lambda_l2': 0.06783022198596762}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:18,979] Trial 150 finished with value: 0.6425370429274819 and parameters: {'n_estimators': 143, 'learning_rate': 0.06608261606267435, 'num_leaves': 87, 'max_depth': 8, 'lambda_l1': 0.010248023450550621, 'lambda_l2': 0.15994196503981462}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:22,879] Trial 151 finished with value: 0.6442328900829535 and parameters: {'n_estimators': 137, 'learning_rate': 0.06746470176072433, 'num_leaves': 82, 'max_depth': 8, 'lambda_l1': 0.00981713270641902, 'lambda_l2': 0.0609784940887927}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:26,796] Trial 152 finished with value: 0.6441656275223173 and parameters: {'n_estimators': 137, 'learning_rate': 0.067724021433531, 'num_leaves': 82, 'max_depth': 8, 'lambda_l1': 0.008265038189084018, 'lambda_l2': 0.0720810556873764}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:30,628] Trial 153 finished with value: 0.6437902609520236 and parameters: {'n_estimators': 137, 'learning_rate': 0.06762338528603222, 'num_leaves': 80, 'max_depth': 8, 'lambda_l1': 0.007166381518829208, 'lambda_l2': 0.05796487348688709}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:34,378] Trial 154 finished with value: 0.6422756215882546 and parameters: {'n_estimators': 134, 'learning_rate': 0.066529982751592, 'num_leaves': 81, 'max_depth': 8, 'lambda_l1': 0.007856783568097268, 'lambda_l2': 0.07184504219636013}. Best is trial 118 with value: 0.6455308163692401.
# [I 2024-04-06 11:25:38,274] Trial 155 finished with value: 0.6441123213517047 and parameters: {'n_estimators': 140, 'learning_rate': 0.06821976243996786, 'num_leaves': 88, 'max_depth': 8, 'lambda_l1': 0.008912439619151283, 'lambda_l2': 0.06459460737269435}. Best is trial 118 with value: 0.6455308163692401.
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] lambda_l2 is set=0.5440164165067815, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5440164165067815
# [LightGBM] [Warning] lambda_l1 is set=1.0861753030922683, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0861753030922683
# [I 2024-04-06 12:02:39,582] Trial 398 finished with value: 0.5943541020837506 and parameters: {'num_leaves': 85, 'n_estimators': 340, 'min_data_in_leaf': 23, 'max_depth': 5, 'learning_rate': 0.02486272029905768, 'lambda_l2': 0.5440164165067815, 'lambda_l1': 1.0861753030922683}. Best is trial 238 with value: 0.654294308183057.
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] lambda_l2 is set=0.5005328177781567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5005328177781567
# [LightGBM] [Warning] lambda_l1 is set=0.5853771739467328, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5853771739467328
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] lambda_l2 is set=0.5005328177781567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5005328177781567
# [LightGBM] [Warning] lambda_l1 is set=0.5853771739467328, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5853771739467328
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008530 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 166
# [LightGBM] [Info] Number of data points in the train set: 63368, number of used features: 36
# [LightGBM] [Info] Start training from score 156908.754640
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] lambda_l2 is set=0.5005328177781567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5005328177781567
# [LightGBM] [Warning] lambda_l1 is set=0.5853771739467328, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5853771739467328
# [I 2024-04-06 12:02:42,750] Trial 399 finished with value: 0.6505284504944575 and parameters: {'num_leaves': 93, 'n_estimators': 268, 'min_data_in_leaf': 29, 'max_depth': -1, 'learning_rate': 0.016146116915686348, 'lambda_l2': 0.5005328177781567, 'lambda_l1': 0.5853771739467328}. Best is trial 238 with value: 0.654294308183057.
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] lambda_l2 is set=0.5396854253893902, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5396854253893902
# [LightGBM] [Warning] lambda_l1 is set=1.228424506946896, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.228424506946896
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] lambda_l2 is set=0.5396854253893902, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5396854253893902
# [LightGBM] [Warning] lambda_l1 is set=1.228424506946896, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.228424506946896
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 166
# [LightGBM] [Info] Number of data points in the train set: 63368, number of used features: 36
# [LightGBM] [Info] Start training from score 156908.754640
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] lambda_l2 is set=0.5396854253893902, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5396854253893902
# [LightGBM] [Warning] lambda_l1 is set=1.228424506946896, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.228424506946896
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] lambda_l2 is set=0.5396854253893902, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5396854253893902
# [LightGBM] [Warning] lambda_l1 is set=1.228424506946896, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.228424506946896
# Random Forest Regressor As Meta Evaluation :
# Root Mean Squared Error (Stacked Model):  68869.42103783607
# R Square (Stacked Model):  0.8757836246448039

# %% [markdown]
# ## MODEL STACKING : BASE LEARNER - XGB & LGBM, META LEARNER - XGBRegressor

# %%
# import optuna
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, r2_score
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# import numpy as np

# def xgb_objective(trial):
#     param_grid = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 150),
#         'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.07),
#         'num_leaves': trial.suggest_int('num_leaves', 80, 100),
#         'max_depth': trial.suggest_categorical('max_depth', [1, 5, 8]),
#         'lambda_l1': trial.suggest_float('lambda_l1', 0, 0.05),
#         'lambda_l2': trial.suggest_float('lambda_l2', 0, 0.2),
#     }
#     model = XGBRegressor(**param_grid)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     return r2_score(y_test, preds)

# with warnings.catch_warnings():
#     warnings.filterwarnings("ignore", message="No further splits with positive gain, best gain: -inf")

#     def lgbm_objective(trial):
#         param_grid = {
#             'num_leaves': trial.suggest_int('num_leaves', 80, 160),
#             'n_estimators': trial.suggest_int('n_estimators', 200, 400),
#             'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 60),
#             'max_depth': trial.suggest_categorical('max_depth', [-1, 5, 8, 12]),
#             'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.2),
#             'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.5, 2.0),
#             'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.5, 2.0)
#         }
#         model = LGBMRegressor(**param_grid)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         return r2_score(y_test, preds)

# xgb_study = optuna.create_study(study_name='XGB OPTUNA', direction='maximize')
# xgb_study.optimize(xgb_objective, n_trials=400)

# lgbm_study = optuna.create_study(study_name='LGBM OPTUNA', direction='maximize')
# lgbm_study.optimize(lgbm_objective, n_trials=400)

# best_xgb_params = xgb_study.best_params
# best_xgb_model = XGBRegressor(**best_xgb_params)
# best_xgb_model.fit(x_train, y_train)

# best_lgbm_params = lgbm_study.best_params
# best_lgbm_model = LGBMRegressor(**best_lgbm_params)
# best_lgbm_model.fit(x_train, y_train)

# xgb_preds = best_xgb_model.predict(x_test)
# lgbm_preds = best_lgbm_model.predict(x_test)

# stacked_features_train = np.column_stack((xgb_preds, lgbm_preds))

# meta_learner = XGBRegressor()
# meta_learner.fit(stacked_features_train, y_test)

# stacked_features_test = np.column_stack((best_xgb_model.predict(x_test), best_lgbm_model.predict(x_test)))
# stacked_predictions = meta_learner.predict(stacked_features_test)

# print('XGB Regressor As Meta Evaluation : ')
# print('Root Mean Squared Error (Stacked Model): ', np.sqrt(mean_squared_error(y_test, stacked_predictions)))
# print('R Square (Stacked Model): ', r2_score(y_test, stacked_predictions))

# %% [markdown]
# ## MODEL STACKING : BASE LEARNER - XGB & LGBM, META LEARNER - LGBMRegressor

# %%
# import optuna
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, r2_score
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# import numpy as np

# def xgb_objective(trial):
#     param_grid = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 150),
#         'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.07),
#         'num_leaves': trial.suggest_int('num_leaves', 80, 100),
#         'max_depth': trial.suggest_categorical('max_depth', [1, 5, 8]),
#         'lambda_l1': trial.suggest_float('lambda_l1', 0, 0.05),
#         'lambda_l2': trial.suggest_float('lambda_l2', 0, 0.2),
#     }
#     model = XGBRegressor(**param_grid)
#     model.fit(x_train, y_train)
#     preds = model.predict(x_test)
#     return r2_score(y_test, preds)

# with warnings.catch_warnings():
#     warnings.filterwarnings("ignore", message="No further splits with positive gain, best gain: -inf")

#     def lgbm_objective(trial):
#         param_grid = {
#             'num_leaves': trial.suggest_int('num_leaves', 80, 160),
#             'n_estimators': trial.suggest_int('n_estimators', 200, 400),
#             'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 60),
#             'max_depth': trial.suggest_categorical('max_depth', [-1, 5, 8, 12]),
#             'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.2),
#             'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.5, 2.0),
#             'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.5, 2.0)
#         }
#         model = LGBMRegressor(**param_grid)
#         model.fit(x_train, y_train)
#         preds = model.predict(x_test)
#         return r2_score(y_test, preds)

# xgb_study = optuna.create_study(study_name='XGB OPTUNA', direction='maximize')
# xgb_study.optimize(xgb_objective, n_trials=400)

# lgbm_study = optuna.create_study(study_name='LGBM OPTUNA', direction='maximize')
# lgbm_study.optimize(lgbm_objective, n_trials=400)

# best_xgb_params = xgb_study.best_params
# best_xgb_model = XGBRegressor(**best_xgb_params)
# best_xgb_model.fit(x_train, y_train)

# best_lgbm_params = lgbm_study.best_params
# best_lgbm_model = LGBMRegressor(**best_lgbm_params)
# best_lgbm_model.fit(x_train, y_train)

# xgb_preds = best_xgb_model.predict(x_test)
# lgbm_preds = best_lgbm_model.predict(x_test)

# stacked_features_train = np.column_stack((xgb_preds, lgbm_preds))

# meta_learner = LGBMRegressor()
# meta_learner.fit(stacked_features_train, y_test)

# stacked_features_test = np.column_stack((best_xgb_model.predict(x_test), best_lgbm_model.predict(x_test)))
# stacked_predictions = meta_learner.predict(stacked_features_test)

# print('LGBM Regressor As Meta Evaluation : ')
# print('Root Mean Squared Error (Stacked Model): ', np.sqrt(mean_squared_error(y_test, stacked_predictions)))
# print('R Square (Stacked Model): ', r2_score(y_test, stacked_predictions))

# %% [markdown]
# # Conclusion

# %% [markdown]
# * During this machine learning project, we tested different models such as XGBoost (XGB), LightGBM (LGBM), and Random Forest (RF) as our base models.
# * To improve the models' performance, we tuned the hyperparameters using Grid Search and Randomized Search methods.
# * Additionally, we used Optuna to further enhance the model settings.
# * Our analysis showed that utilizing model stacking was the most successful approach.
# * Our base learners were XgBoost and LightGBM.
# * We experimented with different metal learners such as Random Forest, XGBoost, LightGBM, Linear Regression and Random Forest gave the best output.
